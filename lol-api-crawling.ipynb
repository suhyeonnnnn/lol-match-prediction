# %% [markdown]
# # 라이엇 게임즈 API에서 게임 정보, 유저정보 수집

# %% [markdown]
# # CHALLENGER

# %%
import requests
import pandas as pd
import requests
import json 
from tqdm import tqdm
import time

# %%
challenger = 'https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key=RGAPI-bcc3c0ab-d42a-4d19-851d-77b812182a79'
r = requests.get(challenger)
league_df = pd.DataFrame(r.json())
league_df.reset_index(inplace=True)
print(league_df)
# Out:
#      index        tier                              leagueId            queue  \
# 0        0  CHALLENGER  d1ff3466-6c02-33b0-8085-9fa6a8b82dd5  RANKED_SOLO_5x5
# 1        1  CHALLENGER  d1ff3466-6c02-33b0-8085-9fa6a8b82dd5  RANKED_SOLO_5x5
# 2        2  CHALLENGER  d1ff3466-6c02-33b0-8085-9fa6a8b82dd5  RANKED_SOLO_5x5
# 3        3  CHALLENGER  d1ff3466-6c02-33b0-8085-9fa6a8b82dd5  RANKED_SOLO_5x5
# 4        4  CHALLENGER  d1ff3466-6c02-33b0-8085-9fa6a8b82dd5  RANKED_SOLO_5x5
# ..     ...         ...                                   ...              ...
# 295    295  CHALLENGER  d1ff3466-6c02-33b0-8085-9fa6a8b82dd5  RANKED_SOLO_5x5
# 296    296  CHALLENGER  d1ff3466-6c02-33b0-8085-9fa6a8b82dd5  RANKED_SOLO_5x5
# 297    297  CHALLENGER  d1ff3466-6c02-33b0-8085-9fa6a8b82dd5  RANKED_SOLO_5x5
# 298    298  CHALLENGER  d1ff3466-6c02-33b0-8085-9fa6a8b82dd5  RANKED_SOLO_5x5
# 299    299  CHALLENGER  d1ff3466-6c02-33b0-8085-9fa6a8b82dd5  RANKED_SOLO_5x5
#
# ...

# %%
league_entries_df = pd.DataFrame(dict(league_df['entries'])).T #dict구조로 되어 있는 entries컬럼 풀어주기
league_df = pd.concat([league_df, league_entries_df], axis=1) #열끼리 결합

league_df = league_df.drop(['index', 'queue', 'name', 'leagueId', 'entries'], axis=1)
league_df.info()
league_df.to_csv('challenger.csv',index=False)#중간저장
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tier          300 non-null    object
#  1   summonerId    300 non-null    object
#  2   summonerName  300 non-null    object
#  3   leaguePoints  300 non-null    object
#  4   rank          300 non-null    object
#  5   wins          300 non-null    object
#  6   losses        300 non-null    object
#  7   veteran       300 non-null    object
#  8   inactive      300 non-null    object
#  9   freshBlood    300 non-null    object
#  10  hotStreak     300 non-null    object
# dtypes: object(11)
# memory usage: 25.9+ KB

# %%
league_df
# Out:
#            tier                                         summonerId  \
# 0    CHALLENGER    CikOuzZUCXOjcvStwAGjM1e_S8FT7wfXYt5jRBrG54TeZco
# 1    CHALLENGER    F7AaFq4Ni_2Yqv3Jyg1CuH6N_fE0s8fe3GO5j5CSfvh2vDU
# 2    CHALLENGER  LmDwC_qgK8Onb_5mbJLJMiVihyM8yS7DP_7vujIA-WjL0W...
# 3    CHALLENGER    vLEbtUKGvUVVBIrAz0PHYm8Pa_xHbTvybUthi_SCjo37O3U
# 4    CHALLENGER    2rypbwkBAx6pjiHMxKbWuDd5YhkPASVsYD7C00mShNHwgVA
# ..          ...                                                ...
# 295  CHALLENGER  hCm2cl_erIOoaoBHxRD9kfQCq-cZLrFmMrdUXAIGe-Q5mf...
# 296  CHALLENGER     oaacAGS3DekFgvE81tXmQ9Ko8ZjXW6fbCeqR04DCA7qS0g
# 297  CHALLENGER     lUmLuw8HUu1KA6HQGpv9p8yf1IbHD0BdFBqMgUdkoDOOZQ
# 298  CHALLENGER  p-pK6IoLHkme0SXsY4PJhpwUDVNETq5qLHXPVZQcVLhxIx...
# 299  CHALLENGER  syTS9NcmOhrYa9NqOhpOHEcF2UfgljlMIuNj8uvi9S_qx1...
#
#     summonerName leaguePoints rank  wins losses veteran inactive freshBlood  \
# 0        가라마바사나다          815    I  1168   1104   False    False       True
# ...

# %% [markdown]
# # GRANDMASTER

# %%
grandmaster = 'https://kr.api.riotgames.com/lol/league/v4/grandmasterleagues/by-queue/RANKED_SOLO_5x5?api_key=RGAPI-4bb9e2ab-cdfd-4bd0-8404-8eec1954c49e'
r = requests.get(grandmaster)
league_df = pd.DataFrame(r.json())
league_df.reset_index(inplace=True)
print(league_df)
# Out:
#      index         tier                              leagueId  \
# 0        0  GRANDMASTER  a37af09b-ecb8-3664-9453-cf2b0138dd6e
# 1        1  GRANDMASTER  a37af09b-ecb8-3664-9453-cf2b0138dd6e
# 2        2  GRANDMASTER  a37af09b-ecb8-3664-9453-cf2b0138dd6e
# 3        3  GRANDMASTER  a37af09b-ecb8-3664-9453-cf2b0138dd6e
# 4        4  GRANDMASTER  a37af09b-ecb8-3664-9453-cf2b0138dd6e
# ..     ...          ...                                   ...
# 695    695  GRANDMASTER  a37af09b-ecb8-3664-9453-cf2b0138dd6e
# 696    696  GRANDMASTER  a37af09b-ecb8-3664-9453-cf2b0138dd6e
# 697    697  GRANDMASTER  a37af09b-ecb8-3664-9453-cf2b0138dd6e
# 698    698  GRANDMASTER  a37af09b-ecb8-3664-9453-cf2b0138dd6e
# 699    699  GRANDMASTER  a37af09b-ecb8-3664-9453-cf2b0138dd6e
#
#                queue                 name  \
# 0    RANKED_SOLO_5x5  Master Yi's Snipers
# 1    RANKED_SOLO_5x5  Master Yi's Snipers
# 2    RANKED_SOLO_5x5  Master Yi's Snipers
# 3    RANKED_SOLO_5x5  Master Yi's Snipers
# ...

# %%
league_entries_df = pd.DataFrame(dict(league_df['entries'])).T #dict구조로 되어 있는 entries컬럼 풀어주기
league_df = pd.concat([league_df, league_entries_df], axis=1) #열끼리 결합

league_df = league_df.drop(['index', 'queue', 'name', 'leagueId', 'entries'], axis=1)
league_df.info()
league_df.to_csv('grandmaster.csv',index=False)#중간저장
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tier          700 non-null    object
#  1   summonerId    700 non-null    object
#  2   summonerName  700 non-null    object
#  3   leaguePoints  700 non-null    object
#  4   rank          700 non-null    object
#  5   wins          700 non-null    object
#  6   losses        700 non-null    object
#  7   veteran       700 non-null    object
#  8   inactive      700 non-null    object
#  9   freshBlood    700 non-null    object
#  10  hotStreak     700 non-null    object
# dtypes: object(11)
# memory usage: 60.3+ KB

# %% [markdown]
# # MASTER

# %%
master = 'https://kr.api.riotgames.com/lol/league/v4/masterleagues/by-queue/RANKED_SOLO_5x5?api_key=RGAPI-4bb9e2ab-cdfd-4bd0-8404-8eec1954c49e'
r = requests.get(master)
league_df = pd.DataFrame(r.json())
league_df.reset_index(inplace=True)
print(league_df)
# Out:
#       index    tier                              leagueId            queue  \
# 0         0  MASTER  dbb721c8-b8fa-3d0c-9727-bfa4eabefc30  RANKED_SOLO_5x5
# 1         1  MASTER  dbb721c8-b8fa-3d0c-9727-bfa4eabefc30  RANKED_SOLO_5x5
# 2         2  MASTER  dbb721c8-b8fa-3d0c-9727-bfa4eabefc30  RANKED_SOLO_5x5
# 3         3  MASTER  dbb721c8-b8fa-3d0c-9727-bfa4eabefc30  RANKED_SOLO_5x5
# 4         4  MASTER  dbb721c8-b8fa-3d0c-9727-bfa4eabefc30  RANKED_SOLO_5x5
# ...     ...     ...                                   ...              ...
# 5341   5341  MASTER  dbb721c8-b8fa-3d0c-9727-bfa4eabefc30  RANKED_SOLO_5x5
# 5342   5342  MASTER  dbb721c8-b8fa-3d0c-9727-bfa4eabefc30  RANKED_SOLO_5x5
# 5343   5343  MASTER  dbb721c8-b8fa-3d0c-9727-bfa4eabefc30  RANKED_SOLO_5x5
# 5344   5344  MASTER  dbb721c8-b8fa-3d0c-9727-bfa4eabefc30  RANKED_SOLO_5x5
# 5345   5345  MASTER  dbb721c8-b8fa-3d0c-9727-bfa4eabefc30  RANKED_SOLO_5x5
#
# ...

# %%
league_entries_df = pd.DataFrame(dict(league_df['entries'])).T #dict구조로 되어 있는 entries컬럼 풀어주기
league_df = pd.concat([league_df, league_entries_df], axis=1) #열끼리 결합

league_df = league_df.drop(['index', 'queue', 'name', 'leagueId', 'entries'], axis=1)
league_df.info()
league_df.to_csv('master.csv',index=False)#중간저장
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5346 entries, 0 to 5345
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tier          5346 non-null   object
#  1   summonerId    5346 non-null   object
#  2   summonerName  5346 non-null   object
#  3   leaguePoints  5346 non-null   object
#  4   rank          5346 non-null   object
#  5   wins          5346 non-null   object
#  6   losses        5346 non-null   object
#  7   veteran       5346 non-null   object
#  8   inactive      5346 non-null   object
#  9   freshBlood    5346 non-null   object
#  10  hotStreak     5346 non-null   object
# dtypes: object(11)
# memory usage: 459.5+ KB

# %%
# 티어별 자료 합치기
challenger = pd.read_csv("challenger.csv")
grandmaster = pd.read_csv("grandmaster.csv")
master = pd.read_csv('master.csv')

tier = pd.concat([challenger, grandmaster, master])
tier.to_csv("tier.csv",index=False)

# %% [markdown]
# # puuid 수집

# %%
summonerNames = list(tier['summonerName'])
summonerNames
# Out:
# ['가라마바사나다',
#  '가을의북',
#  'emowuwu',
#  '챌찍으면롤체만함',
#  '아이린',
#  '기름을넣다',
#  '용호야',
#  'Astrocetus',
#  '하나둘둘셋셋셋',
#  'Mg mid',
#  'seven seconds',
#  'JIAhyfcnlczzyjya',
#  'FA Decky',
#  '죽림초',
#  'hao yun bao bei',
#  '전상득',
#  '윤용호',
#  '다없수질',
#  'mid ten10',
#  'Good luck6',
#  'HLE Asap',
#  '이 차가 식기전에',
#  '순뀨박',
#  'DuDu11',
#  'EIderwood',
#  'jusaka77',
#  '독기품기',
#  'BRO Delight',
#  'Joe and Quinn',
#  'lIllIIlIIlIIlII',
#  '사 용 수',
#  'Shadow 7777k',
#  'KT VicLa',
#  'Shadow HamBak ',
#  'Fisherr',
#  'fuzhu carry',
#  '도브콩',
#  '쭌 베',
#  '단군의청춘부재',
#  'Mung',
#  'PhasedKiller',
#  'Destiny',
#  '참새크면비둘기',
#  'changguiiiiiiiii',
#  'BRO Yaharong',
#  'GGGori',
#  '돼지와함께춤을a',
#  '똥 얏',
#  '디알엑스 태윤',
#  '폭탄치우기',
#  '기모링딩동1',
#  'Gen G Quid',
#  'T1 M1reu',
#  'DK Lucid',
#  '극악법 경탄서멸',
#  'T1 F0rest',
#  'Liiv Effort',
#  'DK Chasy',
#  'jkjkjkjkk',
#  '먼지 한 알',
#  '율천고 최현우',
#  '아이러니2',
#  'Shadow2003',
#  '아라드',
#  'heeseong',
#  'Let me sup',
#  'hong he wo de',
# ...

# %%
api_key = 'RGAPI-4bb9e2ab-cdfd-4bd0-8404-8eec1954c49e'
puuid_urls = []

for summonerName in summonerNames:
    puuid_urls.append('https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/'+summonerName+'?api_key=' + api_key)

# %%
len(puuid_urls)
# Out:
# 6346

# %%
#데이터 프레임 생성
result = {
    "summonerId": [], #merge를 위해 id -> summonerName으로 변경
    "accountId": [],
    "puuid": [],
    "summonerName": [], #merge를 위해 name -> summonerName으로 변경
    "profileIconId": [],
    "revisionDate": [],
    "summonerLevel": []
}

# %%
for puuid_url in tqdm(puuid_urls):
    r = requests.get(puuid_url)
    if r.status_code == 200: #없어진 summoner 제거
        game_data = json.loads(r.text)
        result["summonerId"].append(game_data["id"])
        result["accountId"].append(game_data["accountId"])
        result["puuid"].append(game_data["puuid"])
        result["summonerName"].append(game_data["name"])
        result["profileIconId"].append(game_data["profileIconId"])
        result["revisionDate"].append(game_data["revisionDate"])
        result["summonerLevel"].append(game_data["summonerLevel"])
        
    else:
        print("Error code")
# Out:
#   2%|█▏                                                                              | 98/6346 [00:27<32:06,  3.24it/s]
# Error code
#   2%|█▏                                                                             | 100/6346 [00:28<26:57,  3.86it/s]
# Error code
# Error code
#   2%|█▎                                                                             | 101/6346 [00:28<26:52,  3.87it/s]
# Error code
#   2%|█▎                                                                             | 102/6346 [00:28<25:54,  4.02it/s]
# Error code
#   2%|█▎                                                                             | 103/6346 [00:28<25:24,  4.10it/s]
# Error code
#   2%|█▎                                                                             | 105/6346 [00:29<23:56,  4.34it/s]
# Error code
# Error code
#   2%|█▎                                                                             | 106/6346 [00:29<23:52,  4.36it/s]
# Error code
# ...

# %%
#데이터 프레임 변환 후 export
puuid = pd.DataFrame(result)
puuid.head()
# Out:
#                                           summonerId  \
# 0    CikOuzZUCXOjcvStwAGjM1e_S8FT7wfXYt5jRBrG54TeZco
# 1    F7AaFq4Ni_2Yqv3Jyg1CuH6N_fE0s8fe3GO5j5CSfvh2vDU
# 2  LmDwC_qgK8Onb_5mbJLJMiVihyM8yS7DP_7vujIA-WjL0W...
# 3    vLEbtUKGvUVVBIrAz0PHYm8Pa_xHbTvybUthi_SCjo37O3U
# 4    2rypbwkBAx6pjiHMxKbWuDd5YhkPASVsYD7C00mShNHwgVA
#
#                                            accountId  \
# 0    VLxdt87dRtWb_lONLlQhxrDJY36NkT3G2XosBVfGjNh_RMo
# 1  3_qUrJFIA3prK1S_yb2cWMO0_4SswabkQfZBGpQMD9fUuG...
# 2  HHBIjIcjCkwGrdqy0o3_TDiESqWnBHm7KJIMdpnyLQ3TzT...
# 3  LDCdxgxB4dkc3vvFImpos9oujyyMIbkxxo0jwLmyE6AKq1...
# 4  dCj3PXWybxGZ_apCdx5qZAsf2opl2QZFQ_8oJSRZDtuMoG...
#
#                                                puuid summonerName  \
# 0  iNPzCASacOER8SaZehDrxMpnATiSxnm2pUuhGwOz-8geNO...      가라마바사나다
# 1  i8Z3-QYD7SoJS5-2KbHPElX79Ks6b8R4s-VyE5d3VqnbDR...         가을의북
# 2  obWu1ILFAk4bXnkNmrY-rQq2JOEO8FHHbdNcP26MY17B1u...      emowuwu
# ...

# %%
puuid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1285 entries, 0 to 1284
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   summonerId     1285 non-null   object
#  1   accountId      1285 non-null   object
#  2   puuid          1285 non-null   object
#  3   summonerName   1285 non-null   object
#  4   profileIconId  1285 non-null   int64
#  5   revisionDate   1285 non-null   int64
#  6   summonerLevel  1285 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 70.4+ KB

# %%
puuid.to_csv('puuid.csv', index=False)

# %% [markdown]
# # matchId 수집

# %%
puuids = list(puuid['puuid'])
puuids
# Out:
# ['iNPzCASacOER8SaZehDrxMpnATiSxnm2pUuhGwOz-8geNOkzwYoTlL2c1FmpE-F8yG7qquf8v9y3iQ',
#  'i8Z3-QYD7SoJS5-2KbHPElX79Ks6b8R4s-VyE5d3VqnbDRteVk0aDQblgIzFQTjR-pqaipoym2qBLA',
#  'obWu1ILFAk4bXnkNmrY-rQq2JOEO8FHHbdNcP26MY17B1ublbatcjkLHvUA2mjmoeuNYnJwCoyzqVw',
#  '1BM7qegPZfqEREVMWeSGpbhtxLolx2XpTBFnZa39IkmkYz3NlqDY95hSF7Pwe8ztl7JIjkO9M3SmlQ',
#  'fAyQWGq_nOdJeooQE5jXZaFYjnCSOdvdoPv4iS6BQKUHr8iK2ChonHQtn33LjXGHv0LqWDiy30d6Wg',
#  'VymOGiC0PWaQTdy7BXLiJOOmTfjPY7nTgbOS2RGccqnupVKtpUHuprnCoQu5XWCbRvrXLi2gQP5enA',
#  'bN5aB-Q15EjR4jaKVrOirTWPUFU3MM993rskVoQvgnQx03LvERujlb53VbKwZGLDFys9fyMwprq-hA',
#  'KXegOtlLMX94X20MHrQA3ASTy4TB5D2fHnDaJxsLpDIs6OgztbHtiXjaQwYGeO8u9XvBOjxpI_28ZA',
#  'vptqLVTMSrW37-O00GeWHoHgf-Zi8e-X0Sehe2ovJoK8XJHzrgop_qpQ3Tca6lcNMtyAt1Hp7BKFTw',
#  '_ntQgy8aD3h8hTi4mFUNwVzBJn3EOExMNpTKNHTfFhoZbNK9t3rU8Ynezcj2XwYKSjPQyojF3SDM9Q',
#  '51augaprGi0b8MbEfyxLanhI6GWWJ29vCeI7een-yhZPfxxgFTLOvRBuHJWPhCbtqgqVRcekpifhYA',
# ...

# %%
match_urls = []
for puuid in puuids: #100개 게임 검색
    match_urls.append('https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/'+puuid+'/ids?start=0&count=100&api_key=RGAPI-4bb9e2ab-cdfd-4bd0-8404-8eec1954c49e')

# %%
len(match_urls)
# Out:
# 1285

# %%
match_urls
# Out:
# ['https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/iNPzCASacOER8SaZehDrxMpnATiSxnm2pUuhGwOz-8geNOkzwYoTlL2c1FmpE-F8yG7qquf8v9y3iQ/ids?start=0&count=100&api_key=RGAPI-4bb9e2ab-cdfd-4bd0-8404-8eec1954c49e',
#  'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/i8Z3-QYD7SoJS5-2KbHPElX79Ks6b8R4s-VyE5d3VqnbDRteVk0aDQblgIzFQTjR-pqaipoym2qBLA/ids?start=0&count=100&api_key=RGAPI-4bb9e2ab-cdfd-4bd0-8404-8eec1954c49e',
#  'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/obWu1ILFAk4bXnkNmrY-rQq2JOEO8FHHbdNcP26MY17B1ublbatcjkLHvUA2mjmoeuNYnJwCoyzqVw/ids?start=0&count=100&api_key=RGAPI-4bb9e2ab-cdfd-4bd0-8404-8eec1954c49e',
#  'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/1BM7qegPZfqEREVMWeSGpbhtxLolx2XpTBFnZa39IkmkYz3NlqDY95hSF7Pwe8ztl7JIjkO9M3SmlQ/ids?start=0&count=100&api_key=RGAPI-4bb9e2ab-cdfd-4bd0-8404-8eec1954c49e',
# ...

# %%
match = []
for match_url in tqdm(match_urls):
    r = requests.get(match_url)
    if r.status_code == 200: #없어진 summoner 제거
        game_data = json.loads(r.text)
        for i in range(len(game_data)):
            match.append(game_data[i])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1285/1285 [04:53<00:00,  4.37it/s]

# %%
match = pd.DataFrame(match)

# %%
match.columns = ['matchid']
match.to_csv('match.csv', index=False)

# %% [markdown]
# # 경기 상세 정보 수집

# %%
matches = list(match['matchid'])
matches
# Out:
# ['KR_5560807823',
#  'KR_5560880992',
#  'KR_5560786311',
#  'KR_5560761648',
#  'KR_5560614985',
#  'KR_5560477519',
#  'KR_5560481750',
#  'KR_5560282883',
#  'KR_5559997543',
#  'KR_5560001823',
#  'KR_5559812398',
#  'KR_5558793214',
#  'KR_5558675392',
#  'KR_5558569842',
#  'KR_5558553271',
#  'KR_5558437252',
#  'KR_5558323527',
#  'KR_5558174379',
#  'KR_5558007269',
#  'KR_5557931452',
#  'KR_5557707486',
#  'KR_5557256901',
#  'KR_5557283765',
#  'KR_5557310683',
#  'KR_5557216713',
#  'KR_5557173013',
#  'KR_5557089543',
#  'KR_5557113330',
#  'KR_5557040516',
#  'KR_5556943260',
#  'KR_5556855357',
#  'KR_5556673368',
#  'KR_5556393742',
#  'KR_5556258989',
#  'KR_5556333306',
#  'KR_5556149870',
#  'KR_5556157017',
#  'KR_5555564490',
#  'KR_5555280413',
#  'KR_5555163625',
#  'KR_5555007262',
#  'KR_5554909327',
#  'KR_5554854109',
#  'KR_5554737611',
#  'KR_5554644503',
#  'KR_5554545526',
#  'KR_5554460293',
#  'KR_5554424216',
#  'KR_5554370469',
#  'KR_5554332995',
# ...

# %%
#gamedetail_url 내보내기
gamedetail_urls = []
for matche in matches: #100개 게임 검색
    gamedetail_urls.append('https://asia.api.riotgames.com/lol/match/v5/matches/'+matche+'?api_key=')
                           
gamedetail_urls_df = pd.DataFrame(gamedetail_urls)
gamedetail_urls_df.to_csv('gamedetail_urls.csv',index=False)
